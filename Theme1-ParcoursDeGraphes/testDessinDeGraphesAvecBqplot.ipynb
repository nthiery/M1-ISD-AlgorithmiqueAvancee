# %% [markdown]
# # Tests de dessins de graphes avec bqplot

# %%
G = [ (0,1,87), (0,2,217), (0,4,173),
      (1,5,80),
      (2,6,186), (2,7,103),
      (3,7,183),
      (4,9,502),
      (5,8,250),
      (7,9,167),
      (8,9,84) ]

# %%
import numpy as np
from bqplot import *
from bqplot.marks import Graph
from ipywidgets import Layout

fig_layout = Layout(width='600px', height='600px')
graph = Graph(node_data=list("ABCDEFGHIJ"), link_data=[{'source':i,'target':j,'value':v} for i,j,v in G],
              link_type='line', directed=False)
Figure(marks=[graph], layout=fig_layout)
# Out:
# /opt/miniconda3/envs/test-widgets/lib/python3.6/site-packages/bqplot/traits.py:137: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(a.dtype, np.float):
# Figure(fig_margin={'top': 60, 'bottom': 60, 'left': 60, 'right': 60}, layout=Layout(height='600px', width='600px'), marks=[Graph(colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'], directed=False, interactions={'hover': 'tooltip', 'click': 'select'}, link_data=[{'source': 0, 'target': 1, 'value': 87}, {'source': 0, 'target': 2, 'value': 217}, {'source': 0, 'target': 4, 'value': 173}, {'source': 1, 'target': 5, 'value': 80}, {'source': 2, 'target': 6, 'value': 186}, {'source': 2, 'target': 7, 'value': 103}, {'source': 3, 'target': 7, 'value': 183}, {'source': 4, 'target': 9, 'value': 502}, {'source': 5, 'target': 8, 'value': 250}, {'source': 7, 'target': 9, 'value': 167}, {'source': 8, 'target': 9, 'value': 84}], link_type='line', node_data=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], scales_metadata={'x': {'orientation': 'horizontal', 'dimension': 'x'}, 'y': {'orientation': 'vertical', 'dimension': 'y'}, 'color': {'dimension': 'color'}, 'link_color': {'dimension': 'link_color'}}, tooltip_style={'opacity': 0.9})], scale_x=LinearScale(allow_padding=False, max=1.0, min=0.0), scale_y=LinearScale(allow_padding=False, max=1.0, min=0.0))

# %%
graph.link_data += [{'source': 0, 'target':8}]

# %%
graph.y
# Out:
# array([], dtype=float64)

# %%
type(graph.link_data)
# Out:
# list

# %%
graph.class_traits()
# Out:
# {'_display_callbacks': <traitlets.traitlets.Instance at 0x7f2f806f7080>,
#  '_model_module': <traitlets.traitlets.Unicode at 0x7f2f5f376b70>,
#  '_model_module_version': <traitlets.traitlets.Unicode at 0x7f2f5f376c18>,
#  '_model_name': <traitlets.traitlets.Unicode at 0x7f2f5f2d5e48>,
#  '_msg_callbacks': <traitlets.traitlets.Instance at 0x7f2f806f76a0>,
#  '_property_lock': <traitlets.traitlets.Dict at 0x7f2f80715fd0>,
#  '_states_to_send': <traitlets.traitlets.Set at 0x7f2f806a1048>,
#  '_view_count': <traitlets.traitlets.Int at 0x7f2f80715eb8>,
#  '_view_module': <traitlets.traitlets.Unicode at 0x7f2f5f376ba8>,
#  '_view_module_version': <traitlets.traitlets.Unicode at 0x7f2f5f376be0>,
#  '_view_name': <traitlets.traitlets.Unicode at 0x7f2f5f2d5e80>,
#  'apply_clip': <traitlets.traitlets.Bool at 0x7f2f5f3767f0>,
#  'charge': <traitlets.traitlets.Int at 0x7f2f5f2d5908>,
#  'color': <traittypes.traittypes.Array at 0x7f2f5f2d5c50>,
#  'colors': <traitlets.traitlets.List at 0x7f2f5f2d5b00>,
#  'comm': <traitlets.traitlets.Instance at 0x7f2f80715ef0>,
#  'directed': <traitlets.traitlets.Bool at 0x7f2f5f2d5a90>,
#  'display_legend': <traitlets.traitlets.Bool at 0x7f2f5f376748>,
#  'enable_hover': <traitlets.traitlets.Bool at 0x7f2f5f376978>,
#  'highlight_links': <traitlets.traitlets.Bool at 0x7f2f5f2d5ba8>,
#  'hovered_point': <traitlets.traitlets.Int at 0x7f2f5f2d5da0>,
#  'hovered_style': <traitlets.traitlets.Dict at 0x7f2f5f2d5cc0>,
#  'interactions': <traitlets.traitlets.Dict at 0x7f2f5f2d5b38>,
#  'keys': <traitlets.traitlets.List at 0x7f2f80715f28>,
#  'labels': <traitlets.traitlets.List at 0x7f2f5f3767b8>,
#  'link_color': <traittypes.traittypes.Array at 0x7f2f5f2d5c88>,
#  'link_data': <traitlets.traitlets.List at 0x7f2f5f2d59e8>,
#  'link_distance': <traitlets.traitlets.Float at 0x7f2f5f2d5940>,
#  'link_matrix': <traittypes.traittypes.Array at 0x7f2f5f2d5a20>,
#  'link_type': <traitlets.traitlets.Enum at 0x7f2f5f2d5a58>,
#  'log': <traitlets.traitlets.Instance at 0x7f2f80715a90>,
#  'node_data': <traitlets.traitlets.List at 0x7f2f5f2d59b0>,
#  'preserve_domain': <traitlets.traitlets.Dict at 0x7f2f5f3766d8>,
#  'scales': <traitlets.traitlets.Dict at 0x7f2f5f36d7b8>,
#  'scales_metadata': <traitlets.traitlets.Dict at 0x7f2f5f2d5dd8>,
#  'selected': <traitlets.traitlets.List at 0x7f2f5f376940>,
#  'selected_style': <traitlets.traitlets.Dict at 0x7f2f5f376860>,
#  'tooltip': <traitlets.traitlets.Instance at 0x7f2f5f3769b0>,
#  'tooltip_location': <traitlets.traitlets.Enum at 0x7f2f5f376ac8>,
#  'tooltip_style': <traitlets.traitlets.Dict at 0x7f2f5f3769e8>,
#  'unhovered_style': <traitlets.traitlets.Dict at 0x7f2f5f2d5d30>,
#  'unselected_style': <traitlets.traitlets.Dict at 0x7f2f5f3768d0>,
#  'visible': <traitlets.traitlets.Bool at 0x7f2f5f376828>,
#  'x': <traittypes.traittypes.Array at 0x7f2f5f2d5be0>,
#  'y': <traittypes.traittypes.Array at 0x7f2f5f2d5c18>}

# %%
graph.apply_clip?

# %%
graph.notify_change?

# %%
from RushHour import RushHour

# %%
G = RushHour.solution(1, return_graph=True, verbeux=False)

# %%
len(G)
# Out:
# 1058

# %%
import numpy as np
from bqplot import *
from bqplot.marks import Graph
from ipywidgets import Layout

fig_layout = Layout(width='1200px', height='1200px')

# %%
sommets = G.keys()
rev = {plateau:i  for i,plateau in enumerate(sommets)}

# %%
list(G.values())[1]
# Out:
# ('AR1', +------+
#  |AA   O|
#  |P  Q O|
#  |PXXQ O
#  |P  Q  |
#  |B   CC|
#  |B RRR |
#  +------+)

# %%
link_data = [{'source': rev[value[1]], 'target': rev[key], 'value': value[0]} for key,value in G.items() if value]

# %%
def node(plateau):
    t = {'label': rev[plateau], 'tableau': plateau.tableau()}
    t.update({i: plateau.tableau()[i] for i in range(6)})
    return t

# %%
node_data = [node(plateau) for plateau in sommets]

# %%
graph = Graph(node_data=node_data, link_data=link_data,
              link_type='line', directed=False)
tooltip = Tooltip(fields=list(range(6))+['tableau'], show_labels=False)
graph.tooltip = tooltip
# Voir https://github.com/bloomberg/bqplot/blob/master/examples/Marks/Market%20Map.ipynb
# pour comment mettre un widget comme tooltip et le mettre à jour
Figure(marks=[graph], layout=fig_layout,interaction=PanZoom())
# Out:
# /opt/miniconda3/envs/test-widgets/lib/python3.6/site-packages/bqplot/traits.py:137: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype
D1'}, {'source': 7, 'target': 56, 'value': 'OD1'}, {'source': 7, 'target': 57, 'value': 'QU1'}, {'source': 7, 'target': 58, 'value': 'QD1'}, {'source': 8, 'target': 59, 'value': 'OD1'}, {'source': 8, 'target': 60, 'value': 'QU1'}, {'source': 8, 'target': 61, 'value': 'QD1'}, {'source': 9, 'target': 62, 'value': 'AR4'}, {'source': 9, 'target': 63, 'value': 'QU1'}, {'source': 9, 'target': 64, 'value': 'QD1'}, {'source': 12, 'target': 65, 'value': 'RR1'}, {'source': 12, 'target': 66, 'value': 'RL1'}, {'source': 12, 'target': 67, 'value': 'OD1'}, {'source': 12, 'target': 68, 'value': 'OD2'}, {'source': 12, 'target': 69, 'value': 'OD3'}, {'source': 12, 'target': 70, 'value': 'PU1'}, {'source': 12, 'target': 71, 'value': 'QU1'}, {'source': 13, 'target': 72, 'value': 'RR1'}, {'source': 13, 'target': 73, 'value': 'RL1'}, {'source': 13, 'target': 74, 'value': 'OD1'}, {'source': 13, 'target': 75, 'value': 'OD2'}, {'source': 13, 'target': 76, 'value': 'OD3'}, {'source': 13, 'target': 77, 'value': 'PU1'}, {'source': 13, 'target': 78, 'value': 'QU1'}, {'source': 14, 'target': 79, 'value': 'RR1'}, {'source': 14, 'target': 80, 'value': 'RL1'}, {'source': 14, 'target': 81, 'value': ' ...

# %%
F = Figure(layout=fig_layout);F
# Out:
# Figure(fig_margin={'top': 60, 'bottom': 60, 'left': 60, 'right': 60}, layout=Layout(height='1200px', width='1200px'), scale_x=LinearScale(allow_padding=False, max=1.0, min=0.0), scale_y=LinearScale(allow_padding=False, max=1.0, min=0.0))

# %%
F.marks
# Out:
# []

# %%
import bqplot

# %%
bqplot.marks.

# %%
from bqplot import *
sc_x = LinearScale(min=0,max=10)
sc_y = LinearScale(min=0,max=10)

line = Lines(x=[1,2,3], y=[3,1,2],scales={'x': sc_x, 'y': sc_y}, voiture="X")
F = Figure(marks=[line]); F
# Out:
# /opt/miniconda3/envs/test-widgets/lib/python3.6/site-packages/bqplot/traits.py:137: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(a.dtype, np.float):
# Figure(fig_margin={'top': 60, 'bottom': 60, 'left': 60, 'right': 60}, layout=Layout(min_width='125px'), marks=[Lines(colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'], interactions={'hover': 'tooltip'}, scales={'x': LinearScale(max=10.0, min=0.0), 'y': LinearScale(max=10.0, min=0.0)}, scales_metadata={'x': {'orientation': 'horizontal', 'dimension': 'x'}, 'y': {'orientation': 'vertical', 'dimension': 'y'}, 'color': {'dimension': 'color'}}, tooltip_style={'opacity': 0.9}, x=array([1, 2, 3]), y=array([3, 1, 2]))], scale_x=LinearScale(allow_padding=False, max=1.0, min=0.0), scale_y=LinearScale(allow_padding=False, max=1.0, min=0.0))

# %%
line.close_path = True
line.fill = 'inside'

# %%
line.close
# Out:
# <bound method Widget.close of Lines(close_path=True, colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'], fill='inside', interactions={'hover': 'tooltip'}, scales={'x': LinearScale(max=10.0, min=0.0), 'y': LinearScale(max=10.0, min=0.0)}, scales_metadata={'x': {'orientation': 'horizontal', 'dimension': 'x'}, 'y': {'orientation': 'vertical', 'dimension': 'y'}, 'color': {'dimension': 'color'}}, tooltip_style={'opacity': 0.9}, x=array([1, 2, 3]), y=array([3, 1, 2]))>

# %%
F.marks = [line]

# %%
line.colors = ['red']

# %%
line.voiture
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-5cd6ba26e867> in <module>()
# ----> 1 line.voiture
#
# AttributeError: 'Lines' object has no attribute 'voiture'

# %%
line.fill = 'inside'

# %%
def f(line, event):
    line.colors=['blue']
line.on_click(f)

# %%
line.on_background_click?

# %%
line.on_element_click(f)

# %%
line.border
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-6f6866910852> in <module>()
# ----> 1 line.border
#
# AttributeError: 'Lines' object has no attribute 'border'
